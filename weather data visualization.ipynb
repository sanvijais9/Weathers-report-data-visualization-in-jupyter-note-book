# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
weather = pd.read_csv("C:\\Users\shashi\Desktop\weathers.csv")

# %%
weather.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  01-01-2012            0.0      12.8       5.0   4.7  drizzle
# 1  02-01-2012           10.9      10.6       2.8   4.5     rain
# 2  03-01-2012            0.8      11.7       7.2   2.3     rain
# 3  04-01-2012           20.3      12.2       5.6   4.7     rain
# 4  05-01-2012            1.3       8.9       2.8   6.1     rain

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1461 non-null   object
#  1   precipitation  1461 non-null   float64
#  2   temp_max       1461 non-null   float64
#  3   temp_min       1461 non-null   float64
#  4   wind           1461 non-null   float64
#  5   weather        1461 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 68.6+ KB

# %%
sns.histplot(weather['temp_max'])
# Out:
# <AxesSubplot:xlabel='temp_max', ylabel='Count'>

# %%
sns.jointplot(x=weather['temp_max'],y=weather['temp_min'])

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1461 non-null   object
#  1   precipitation  1461 non-null   float64
#  2   temp_max       1461 non-null   float64
#  3   temp_min       1461 non-null   float64
#  4   wind           1461 non-null   float64
#  5   weather        1461 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 68.6+ KB

# %%
sns.pairplot(weather[['wind','temp_min','temp_max']])

# %%
sns.stripplot(x=weather['temp_max'],y=weather['temp_min'])
# Out:
# <AxesSubplot:xlabel='temp_max', ylabel='temp_min'>
